# %%
# !pip install weaviate-client langchain tiktoken pypdf rapidocr-onnxruntime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 368.3/368.3 kB 19.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.8/997.8 kB 71.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 79.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 131.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 241.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 146.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 270.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 144.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 308.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 287.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.1/149.1 kB 251.1 MB/s eta 0:00:00
# ...

# %%
WEAVIATE_CLUSTER="https://tf0r6kaitlmtde3kjyra.c0.us-west3.gcp.weaviate.cloud"
WEAVIATE_API_KEY="m5iIYq8PmIqB7y5i5FSmqYU7LExAvaYDHLqo"

# %%
# !pip install -U langchain-community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 58.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 209.2 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain.vectorstores import Weaviate
import weaviate

WEAVIATE_URL = WEAVIATE_CLUSTER
WEAVIATE_API_KEY = WEAVIATE_API_KEY

client = weaviate.Client(
    url=WEAVIATE_URL, auth_client_secret=weaviate.AuthApiKey(WEAVIATE_API_KEY)
)
# Out:
# /opt/app-root/lib64/python3.9/site-packages/weaviate/__init__.py:143: DeprecationWarning: Dep010: Importing AuthApiKey from weaviate is deprecated. Import AuthApiKey from its module: weaviate.auth
#   _Warnings.root_module_import(name, map_[name])
# /opt/app-root/lib64/python3.9/site-packages/weaviate/warnings.py:162: DeprecationWarning: Dep016: Python client v3 `weaviate.Client(...)` connections and methods are deprecated. Update
#             your code to use Python client v4 `weaviate.WeaviateClient` connections and methods.
#
#             For Python Client v4 usage, see: https://weaviate.io/developers/weaviate/client-libraries/python
#             For code migration, see: https://weaviate.io/developers/weaviate/client-libraries/python/v3_v4_migration
#
#   warnings.warn(

# %%
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 118.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 307.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 249.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 253.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 273.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 224.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 135.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 201.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 30.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 105.3 MB/s eta 0:00:0000:0100:01
# ...

# %%
# specify embedding model (using huggingface sentence transformer)
from langchain.embeddings import HuggingFaceEmbeddings
embedding_model_name = "sentence-transformers/all-mpnet-base-v2"
embeddings = HuggingFaceEmbeddings(
model_name=embedding_model_name,
)
# Out:
# /opt/app-root/lib64/python3.9/site-packages/langchain_core/_api/deprecation.py:141: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /opt/app-root/lib64/python3.9/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# 2024-08-23 06:18:54.557395: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("HR-DigivateLabs-Leave-Policy.pdf", extract_images=True)
pages = loader.load()

# %%
# Split text into chunks
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
docs = text_splitter.split_documents(pages)

# %%
vector_db = Weaviate.from_documents(
    docs, embeddings, client=client, by_text=False
)

# %%
print(vector_db.similarity_search("what is Guidelines?", k=3)[2].page_content)
# Out:
# HR-Digivate Labs -Leave-Policy
#
#
#   Policy Objective :
#
# To provide a composite leave program and also to encourage employees to plan and avail leave in
# accordance with the statutory obligations of the company. We encourage utilization of accrued leaves in a
# planned manner, so that it facilitates enjoyment and well deserved break from work, without impacting
# organization‟s functions.
#
#   Policy Statement  & Entitlement :
# o Earned Leave
# o Casual & Sick Leave
# o Maternity Leave
# o Paternity Leave
# o National & Festival Holidays
# o Compensatory Leave
#
# Guidelines
#
# Leave of absence should be planned and applied for in advance, either through attendance portal (Payasia) .
# In the event of unforeseen circumstances, leave of absence may be taken with verbal approval from reporting
# manager and is to be regularized on the date of joining back duties. All leave of absence must be approved

# %%
from langchain.prompts import ChatPromptTemplate
from langchain import HuggingFaceHub
import os

template="""You are an assistant for question-answering tasks.
Use the following pieces of retrieved context to answer the question.
If you don't know the answer, just say that you don't know.
keep the answer concise. Please provide the complete answer.
Question: {question}
Answer: """
prompt= ChatPromptTemplate.from_template(template)

os.environ['huggingfacehub_api_token'] = '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'

huggingfacehub_api_token = os.getenv('huggingfacehub_api_token')

model = HuggingFaceHub(
    huggingfacehub_api_token=huggingfacehub_api_token,
    repo_id="mistralai/Mistral-7B-Instruct-v0.1",
    model_kwargs={"temperature":0.5, "max_length":200}
)

from langchain.schema.runnable import RunnablePassthrough
from langchain.schema.output_parser import StrOutputParser

output_parser=StrOutputParser()
retriever=vector_db.as_retriever()

rag_chain = (
    {"context": retriever,  "question": RunnablePassthrough()}
    | prompt
    | model
    | output_parser
)

# %%
print(rag_chain.invoke("what are Guidelines?"))
# Out:
# Human: You are an assistant for question-answering tasks.
# Use the following pieces of retrieved context to answer the question.
# If you don't know the answer, just say that you don't know.
# keep the answer concise. Please provide the complete answer.
# Question: what are Guidelines?
# Answer:
# Guidelines are instructions or rules that provide direction or advice on how to do something. They can be formal or informal and are often used in various fields such as business, education, and healthcare. Guidelines are meant to help individuals or organizations make informed decisions and take appropriate actions.

# %%
print(rag_chain.invoke("how can we take maternity leave?"))
# Out:
# Human: You are an assistant for question-answering tasks.
# Use the following pieces of retrieved context to answer the question.
# If you don't know the answer, just say that you don't know.
# keep the answer concise. Please provide the complete answer.
# Question: how can we take maternity leave?
# Answer:
#
# Maternity leave is a type of leave granted to employees who are pregnant or have recently given birth. The exact process for taking maternity leave can vary depending on the company and the country, but it typically involves providing notice to the employer, filling out necessary paperwork, and providing any required documentation, such as a doctor's note. Employees may also be required to provide notice of their intention to take maternity leave prior to the actual leave period. It is

# %%
print(rag_chain.invoke("what are carry forward leave?"))
# Out:
# Human: You are an assistant for question-answering tasks.
# Use the following pieces of retrieved context to answer the question.
# If you don't know the answer, just say that you don't know.
# keep the answer concise. Please provide the complete answer.
# Question: what are carry forward leave?
# Answer:
# Carry forward leave refers to a type of leave that is granted to employees when they are unable to take their annual vacation due to unforeseen circumstances such as illness or family emergencies. The leave may be taken at a later date, typically within the next two years, and is usually paid at the employee's regular rate of pay. It is important to note that not all companies offer carry forward leave, and the amount of leave that can be carried forward may vary depending on the

# %%
print(rag_chain.invoke("what are different types of maternity leave?"))
# Out:
# Human: You are an assistant for question-answering tasks.
# Use the following pieces of retrieved context to answer the question.
# If you don't know the answer, just say that you don't know.
# keep the answer concise. Please provide the complete answer.
# Question: what are different types of maternity leave?
# Answer: 12 weeks paid maternity leave, unpaid maternity leave, parental leave, adoption leave, and shared parental leave.

# %%
print(rag_chain.invoke("what are difference between maternity leave and casual leave? Give answer in tabular form"))
# Out:
# Human: You are an assistant for question-answering tasks.
# Use the following pieces of retrieved context to answer the question.
# If you don't know the answer, just say that you don't know.
# keep the answer concise. Please provide the complete answer.
# Question: what are difference between maternity leave and casual leave? Give answer in tabular form
# Answer:
# | Maternity Leave | Casual Leave |
# | --- | --- |
# | Paid leave given to women who have recently given birth | Paid leave given for a variety of reasons, such as illness or personal matters |
# | Duration is usually determined by the number of weeks or months after the birth | Duration is usually determined by the employer and can vary |
# | Typically provided for a specific period of time (e.g. 12 weeks) |

# %%
print(rag_chain.invoke("what is machine learning"))
# Out:
# Human: You are an assistant for question-answering tasks.
# Use the following pieces of retrieved context to answer the question.
# If you don't know the answer, just say that you don't know.
# keep the answer concise. Please provide the complete answer.
# Question: what is machine learning
# Answer:  Machine learning is a subset of artificial intelligence that involves the use of algorithms to enable computers to learn from data, identify patterns, and make predictions without explicit instructions.
